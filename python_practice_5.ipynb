# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
    def __init__(self, address, floors, material="Concrete"):
        self.address = address  # Адреса
        self.floors = floors  # Поверх
        self.material = material  # Матеріали будівлі(за замовчуванням "Concrete")

    def get_info(self):
        """Метод для отримання інформації про будівлю"""
        return f"Будівля за адресою {self.address} має {self.floors} поверхів, матеріал: {self.material}."

    def renovate(self, new_material):
        """Метод для оновлення матеріалу будівлі"""
        self.__material = new_material
        return f"Будівлю за адресою {self.address} оновлено, новий матеріал: {self.material}."

# Приклад
my_building = Building("Street 123", 5)
print(my_building.get_info())
print(my_building.renovate("Brick"))
print(my_building.get_info())
# Out:
# Будівля за адресою Street 123 має 5 поверхів, матеріал: Concrete.
# Будівлю за адресою Street 123 оновлено, новий матеріал: Concrete.
# Будівля за адресою Street 123 має 5 поверхів, матеріал: Concrete.

# %% [markdown]
# В процесі виконання практичної, я на своєму досвіді зрозумів, чому не можна перестворювати клас в колабі. Помилка у верху створилася через цей мій експеремент. Якщо ви зможете сбоси среду помилка повина вирішитися. На жаль, я не знаю як це робити в колабі.
#
# Вже вирішив питання через Kaggle)

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
my_building1 = Building("Street 231", 5)
my_building2 = Building("Street 312", 10, "Brick")

# Отримання значення атрибуту у першого об'єкта
print(my_building1.material)  # Прогнозований output "Concrete"

# Виклик методу на другому об'єкті
print(my_building2.get_info())
# Out:
# Concrete
# Будівля за адресою Street 312 має 10 поверхів, матеріал: Brick.

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
# Замість створення нового, перестворюю старий
class Building:
    def __init__(self, address, floors, material="Concrete"):
        self.address = address  # Публічний атрибут
        self._floors = floors  # Захищений атрибут
        self.__material = material  # Приватний атрибут

    def get_info(self):
        """Метод для отримання інформації про будівлю"""
        return f"Будівля за адресою {self.address} має {self._floors} поверхів, матеріал: {self.__material}."

    def renovate(self, new_material):
        """Метод для оновлення матеріалу будівлі"""
        self.__material = new_material
        return f"Будівлю за адресою {self.address} оновлено, новий матеріал: {self.__material}."

my_building = Building("Street 123", 5)


# Доступ до атрибутів
print(my_building.address)  # Доступний
print(my_building._floors)  # Можна отримати значення, але зазвичай не слід

# Виклик приватного атрибута напряму
try:
    print(my_building.__material)  # Викличе помилку атрибуції("AttributeError")
except AttributeError:
    print("AttributeError: Неможливо отримати прямий доступ до приватного атрибута __material.")

# ChatGPT підказав такий варіант для обходу цього обмеження. Поки про це мало, що можу сказати: тільки заглиблююсь в питання.
print(my_building._Building__material)
# Out:
# Street 123
# 5
# AttributeError: Неможливо отримати прямий доступ до приватного атрибута __material.
# Concrete

# %% [markdown]
# Як і слід було очікувати, публічний та захищений атрибути загалом доступні без використання складних методів. Однак приватний атрибут безпосередньому доступу не підлягає. Втім, навіть його можна отримати, застосовуючи обхідні підходи.

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self — це поточний екземпляр класу, який дозволяє звертатися до його атрибутів і методів. Метод __init__ же є вбудованим механізмом ініціалізації нового об'єкта, що забезпечує передачу початкових значень його атрибутам.
#
# Чесно кажучи, ці дві концепції я розумію на практичному рівні ("...тут потрібно це написати, тут змінювати не слід..."), ніж у вигляді визначень.

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
# Клас 3D-фігура
class Shape3D:
    def get_volume(self):
        """Метод для отримання об'єму фігури"""
        return 0

    def __add__(self, other):
        """Метод для складання об'ємів двох 3D-фігур"""
        if isinstance(other, Shape3D):
            return self.get_volume() + other.get_volume()
        raise TypeError("Можна додавати лише екземпляри класу Shape3D")

# Приклад
shape1 = Shape3D()
shape2 = Shape3D()
print(shape1 + shape2)  # Виведе 0
# Out:
# 0

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
import math # взяв бібліотеку для числа пі
# Дочірній клас Куб
class Cube(Shape3D):
    def __init__(self, side_length):
        self.side_length = side_length

    def get_volume(self):
        """Розрахунок об'єму куба"""
        return self.side_length ** 3

# Дочірній клас Циліндр
class Cylinder(Shape3D):
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def get_volume(self):
        """Розрахунок об'єму циліндра"""
        return math.pi * (self.radius ** 2) * self.height

cube = Cube(3)
cylinder = Cylinder(2, 5)

# Обчислення загального об'єму
print(f"Об'єм куба: {cube.get_volume()}")
print(f"Об'єм циліндра: {cylinder.get_volume()}")
print(f"Сумарний об'єм: {cube + cylinder}")
# Out:
# Об'єм куба: 27
# Об'єм циліндра: 62.83185307179586
# Сумарний об'єм: 89.83185307179586

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(isinstance(cube, Shape3D))  # True, оскільки cube є екземпляром Shape3D
print(isinstance(cylinder, Cube))  # False, оскільки cylinder не є екземпляром Cube
print(issubclass(Cube, Shape3D))  # True, оскільки Cube є підкласом Shape3D
print(issubclass(Shape3D, Cube))  # False, оскільки Shape3D не є підкласом Cube
# Out:
# True
# False
# True
# False

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
    def __init__(self, wallet_id, balance=0.0):
        self.__id = wallet_id  # Приватний ідентифікатор гаманця
        self.__balance = balance  # Приватний баланс

    @property
    def balance(self):
        """Отримання балансу"""
        return self.__balance

    @balance.setter
    def balance(self, amount):
        """Забороняємо прямий запис балансу"""
        raise AttributeError("Зміна балансу напряму заборонена. Використовуйте методи поповнення або зняття коштів.")

    def deposit(self, amount):
        """Поповнення балансу"""
        if amount > 0:
            self.__balance += amount
            return f"Гаманець {self.__id} поповнено на {amount}. Новий баланс: {self.__balance}"
        return "Сума поповнення має бути більшою за 0."

    def withdraw(self, amount):
        """Зняття коштів"""
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            return f"З гаманця {self.__id} знято {amount}. Новий баланс: {self.__balance}"
        return "Недостатньо коштів або некоректна сума."

# Приклад
wallet = EWallet("Wallet_1234", 100.0)
print(wallet.deposit(50))  # Поповнення на 50
print(wallet.withdraw(30))  # Зняття 30
print(wallet.balance)  # Отримання балансу
# Out:
# Гаманець Wallet_1234 поповнено на 50. Новий баланс: 150.0
# З гаманця Wallet_1234 знято 30. Новий баланс: 120.0
# 120.0

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"{self.name}: {self.price} грн"

class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        """Додає товар до кошика"""
        self.items.append(item)
        return f"Товар {item.name} додано до кошика."

    def remove_item(self, item_name):
        """Видаляє товар з кошика за ім'ям"""
        for item in self.items:
            if item.name == item_name:
                self.items.remove(item)
                return f"Товар {item_name} видалено з кошика."
        return "Товар не знайдено у кошику."

    def display_items(self):
        """Відображає список товарів у кошику"""
        if not self.items:
            return "Кошик порожній."
        return "\n".join(str(item) for item in self.items)

# Приклад
cart = ShoppingCart()
item1 = Item("Яблуко", 15)
item2 = Item("Молоко", 35)

print(cart.add_item(item1))
print(cart.add_item(item2))
print(cart.display_items())
print(cart.remove_item("Яблуко"))
print(cart.display_items())
# Out:
# Товар Яблуко додано до кошика.
# Товар Молоко додано до кошика.
# Яблуко: 15 грн
# Молоко: 35 грн
# Товар Яблуко видалено з кошика.
# Молоко: 35 грн

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
import math

class Vehicle:
    def __init__(self, brand, production_age):
        self.brand = brand  # Виробник автомобіля
        self.production_age = production_age  # Вік автомобіля

    def get_vehicle_info(self):
        """Повертає інформацію про транспортний засіб"""
        return f"Марка: {self.brand}, Вік: {self.production_age} років."

class Engine:
    def __init__(self, type, size):
        self.type = type  # Тип двигуна
        self.size = size  # Об'єм двигуна в літрах

    def get_engine_info(self):
        """Повертає інформацію про двигун"""
        return f"Тип двигуна: {self.type}, Об'єм: {self.size} л."

class Car(Vehicle, Engine):
    def __init__(self, brand, production_age, type, size):
        Vehicle.__init__(self, brand, production_age)
        Engine.__init__(self, type, size)

    def get_car_info(self):
        """Повертає повну інформацію про автомобіль"""
        return f"{self.get_vehicle_info()} {self.get_engine_info()}"

car = Car("Toyota", 5, "Бензиновий", 2.0)

# Вивід інформації про автомобіль
print(car.get_car_info())

# Вивід MRO
print(Car.mro())
# Out:
# Марка: Toyota, Вік: 5 років. Тип двигуна: Бензиновий, Об'єм: 2.0 л.
# [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
# Створення рядка з 4 різними символами
string = "abcd"

# Створення ітератора
iterator = iter(string)

# Виклик next() 5 разів
print(next(iterator))  # 'a'
print(next(iterator))  # 'b'
print(next(iterator))  # 'c'
print(next(iterator))  # 'd'

# П'ята спроба викличе StopIteration
try:
    print(next(iterator))
except StopIteration:
    print("Ітерація завершена: більше елементів немає.")
# Out:
# a
# b
# c
# d
# Ітерація завершена: більше елементів немає.

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %% [markdown]
# Таким чином, буде тільки створенна помилка "TypeError"

# %%
try:
    print(next(string))  # Викличе TypeError
except TypeError:
    print("TypeError: Рядок не є ітератором, необхідно використовувати iter(string).")
# Out:
# TypeError: Рядок не є ітератором, необхідно використовувати iter(string).

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Ітерабельні об'єкти, такі як рядки та списки, містять дані та можуть бути перетворені на ітератор(як в попередньому завданні), тоді як ітератор вже містить механізм поступового отримання елементів, використовуючи функцію next()

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class DaysOfWeekIterator:
    def __init__(self):
        self.days = ["Понеділок", "Вівторок", "Середа", "Четвер", "П'ятниця", "Субота", "Неділя"]
        self.index = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.index < len(self.days):
            day = self.days[self.index]
            self.index += 1
            return day
        raise StopIteration

# Створення ітератора
week_iterator = DaysOfWeekIterator()

# Виклик next() для кожного дня тижня
print(next(week_iterator))  # Понеділок
print(next(week_iterator))  # Вівторок
print(next(week_iterator))  # Середа
print(next(week_iterator))  # Четвер
print(next(week_iterator))  # П'ятниця
print(next(week_iterator))  # Субота
print(next(week_iterator))  # Неділя

# Вихід за межі списку викличе StopIteration
try:
    print(next(week_iterator))
except StopIteration:
    print("Ітерація завершена: більше днів немає.")
# Out:
# Понеділок
# Вівторок
# Середа
# Четвер
# П'ятниця
# Субота
# Неділя
# Ітерація завершена: більше днів немає.

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
